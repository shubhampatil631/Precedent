# %% [markdown]
# # Brand Selection & Dataset Exploration
#
# Compare top candidate brands from `twcs.csv` (e.g. AmericanAir, AppleSupport, AmazonHelp, Delta) on:
# - Total tweet & thread counts
# - Resolution vs. Handoff rate
# - Single-turn vs. Multi-turn distribution
# - Intent diversity

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load raw data sample or full CSV when available
# df = pd.read_csv('../data/raw/twcs.csv', nrows=100000)
print("Exploration notebook ready.")
